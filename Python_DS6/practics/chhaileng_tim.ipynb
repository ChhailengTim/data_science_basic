# %% [markdown]
# <h1><center> Data Analysis: Introduction to Pandas </center></h1>

# %% [markdown]
# <h2> Part I. Filtering and Sorting Data </h2>

# %% [markdown]
# <i>Example 1. Import the necessary libraries</i>

# %%
import pandas as pd

# %% [markdown]
# <i>Example 2. Import the dataset from the local file </i>

# %%
order_list = pd.read_csv('./order_list.csv', sep = '\t')
order_list
# Out:
#         id  quantity                                   food  \
# 0        1         1           Chips and Fresh Tomato Salsa
# 1        1         1                                   Izze
# 2        1         1                       Nantucket Nectar
# 3        1         1  Chips and Tomatillo-Green Chili Salsa
# 4        2         2                           Chicken Bowl
# ...    ...       ...                                    ...
# 4617  1833         1                          Steak Burrito
# 4618  1833         1                          Steak Burrito
# 4619  1834         1                     Chicken Salad Bowl
# 4620  1834         1                     Chicken Salad Bowl
# 4621  1834         1                     Chicken Salad Bowl
#
#                                             description unit_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# ...

# %% [markdown]
# <b>Exercise 1. Display the first 5 orders of the dataset.</b>

# %%
display5 = order_list.head(5)
display5
# Out:
#    id  quantity                                   food  \
# 0   1         1           Chips and Fresh Tomato Salsa
# 1   1         1                                   Izze
# 2   1         1                       Nantucket Nectar
# 3   1         1  Chips and Tomatillo-Green Chili Salsa
# 4   2         2                           Chicken Bowl
#
#                                          description unit_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# <b>Exercise 2. How many order records in the dataset?</b>

# %%
order_record = order_list.shape[0]
order_record
# Out:
# 4622

# %% [markdown]
# <b>Exercise 3. How many attributes in this dataset? </b>

# %%
dataset = order_list.shape[1]
dataset
# Out:
# 5

# %% [markdown]
# <b>Exercise 4. What information do we have from the dataset?</b>

# %%
information = order_list.columns
information
# Out:
# Index(['id', 'quantity', 'food', 'description', 'unit_price'], dtype='object')

# %% [markdown]
# <b>Exercise 5. How many orders in total?

# %%
total_order = order_list['id'].unique().size
total_order
# Out:
# 1834

# %% [markdown]
# <b>Exercise 6. Calculate the total income in this dataset.</b>

# %%
#Convert unit price to float (No $)
prices = []
for value in order_list.unit_price:
    value_f = float(value[1: -1])
    prices.append(value_f)
order_list.unit_price = prices
order_list.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       2 prices = []
#       3 for value in order_list.unit_price:
# ----> 4     value_f = float(value[1: -1])
#       5     prices.append(value_f)
#       6 order_list.unit_price = prices
#
# TypeError: 'float' object is not subscriptable

# %%
order_list.head()
# Out:
#    id  quantity                                   food  \
# 0   1         1           Chips and Fresh Tomato Salsa
# 1   1         1                                   Izze
# 2   1         1                       Nantucket Nectar
# 3   1         1  Chips and Tomatillo-Green Chili Salsa
# 4   2         2                           Chicken Bowl
#
#                                          description  unit_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
order_list['total_price'] = order_list['unit_price'] * order_list['quantity']
total_price = order_list['total_price'].sum()
total_price
# Out:
# '$2.39 $3.39 $3.39 $2.39 $16.98 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $17.98 $1.69 $17.50 $17.50 $4.45 $8.49 $2.39 $
# ...

# %% [markdown]
# <b>Exercise 7. Find the average income for each order?</b>

# %%
average_income = (order_list[['id', 'total_price']].groupby('id', as_index=False).agg(total_by_order=('total_price', 'sum')))
average_income['total_by_order'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 average_income = (order_list[['id', 'total_price']].groupby('id', as_index=False).agg(total_by_order=('total_price', 'sum')))
# ----> 2 average_income['total_by_order'].mean()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
# ...

# %% [markdown]
# <b>Exercise 8. How many different foods are ordered?</b>

# %%
dif_food = order_list.groupby('food').size().reset_index(name='count')
dif_food
# Out:
#                                      food  count
# 0                       6 Pack Soft Drink     54
# 1                           Barbacoa Bowl     66
# 2                        Barbacoa Burrito     91
# 3                   Barbacoa Crispy Tacos     11
# 4                     Barbacoa Salad Bowl     10
# 5                     Barbacoa Soft Tacos     25
# 6                           Bottled Water    162
# 7                                    Bowl      2
# 8                                 Burrito      6
# 9                             Canned Soda    104
# 10                      Canned Soft Drink    301
# 11                          Carnitas Bowl     68
# 12                       Carnitas Burrito     59
# 13                  Carnitas Crispy Tacos      7
# 14                         Carnitas Salad      1
# 15                    Carnitas Salad Bowl      6
# 16                    Carnitas Soft Tacos     40
# 17                           Chicken Bowl    726
# ...

# %% [markdown]
# <b>Exercise 9. Display the food which has the highest total quantity sold, and its quantity.</b>

# %%
highest_order = dif_food.sort_values(by='count', ascending=False).head(1)
highest_order
# Out:
#             food  count
# 17  Chicken Bowl    726

# %% [markdown]
# <b>Exercise 10. What is the most frequently ordered food item?</b>

# %%
frequent_food = highest_order['food'].values[0]
most_frequent = order_list[order_list['food'] == frequent_food]
most_frequent
# Out:
#         id  quantity          food  \
# 4        2         2  Chicken Bowl
# 5        3         1  Chicken Bowl
# 13       7         1  Chicken Bowl
# 19      10         1  Chicken Bowl
# 26      13         1  Chicken Bowl
# ...    ...       ...           ...
# 4590  1825         1  Chicken Bowl
# 4591  1825         1  Chicken Bowl
# 4595  1826         1  Chicken Bowl
# 4599  1827         1  Chicken Bowl
# 4604  1828         1  Chicken Bowl
#
#                                             description unit_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...     $8.49
# ...                                                 ...        ...
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...    $11.25
# ...
