# %%
import pandas as pd

# %%
df1 = pd.read_csv('true_cost_fast_fashion.csv')
df1
# Out:
#            Brand    Country  Year  Monthly_Production_Tonnes  \
# 0          Shein  Indonesia  2017                     574.51
# 1     Forever 21    Vietnam  2024                     394.50
# 2         Uniqlo      India  2024                     310.23
# 3     Forever 21        USA  2017                     218.65
# 4           Zara  Indonesia  2016                    1005.84
# ...          ...        ...   ...                        ...
# 2995        Zara      India  2020                     549.36
# 2996       Shein        USA  2021                     670.54
# 2997        Zara      China  2023                     370.31
# 2998       Shein     Brazil  2015                     649.20
# 2999        Zara      India  2018                     602.77
#
#       Avg_Item_Price_USD  Release_Cycles_Per_Year  Carbon_Emissions_tCO2e  \
# 0                  19.31                       16                11421.58
# 1                   9.30                       20                 5571.01
# ...

# %%
df2 = pd.read_csv('pet_adoption_center.csv')
df2
# Out:
#     pet_id pet_name  species               breed  age_years  gender    color  \
# 0    P0001   Sandra      Dog   Yorkshire Terrier          2  Female    White
# 1    P0002    Brian      Cat           Tonkinese          1  Female   Golden
# 2    P0003  Timothy     Bird       Amazon Parrot          4    Male  Spotted
# 3    P0004     Karl      Dog     German Shepherd          1  Female    White
# 4    P0005    Sarah   Rabbit               Dutch          1  Female  Spotted
# ..     ...      ...      ...                 ...        ...     ...      ...
# 195  P0196  Melissa  Hamster             Chinese          8    Male    White
# 196  P0197    Ricky      Dog  Labrador Retriever          4  Female   Golden
# 197  P0198    Carly   Rabbit       Flemish Giant          5    Male  Spotted
# 198  P0199      Don      Dog          Great Dane          1    Male    Mixed
# 199  P0200    Caleb     Bird              Canary          5    Male   Golden
#
# ...

# %%
merged_df = pd.concat([df1, df2])
merged_df
# Out:
#           Brand    Country    Year  Monthly_Production_Tonnes  \
# 0         Shein  Indonesia  2017.0                     574.51
# 1    Forever 21    Vietnam  2024.0                     394.50
# 2        Uniqlo      India  2024.0                     310.23
# 3    Forever 21        USA  2017.0                     218.65
# 4          Zara  Indonesia  2016.0                    1005.84
# ..          ...        ...     ...                        ...
# 195         NaN        NaN     NaN                        NaN
# 196         NaN        NaN     NaN                        NaN
# 197         NaN        NaN     NaN                        NaN
# 198         NaN        NaN     NaN                        NaN
# 199         NaN        NaN     NaN                        NaN
#
#      Avg_Item_Price_USD  Release_Cycles_Per_Year  Carbon_Emissions_tCO2e  \
# 0                 19.31                     16.0                11421.58
# ...
